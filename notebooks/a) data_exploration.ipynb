# %% [markdown]
# # CAPPIMU INITIAL DATA READ - SUBJECTS 1-15

# %% [markdown]
# ## Data: Taken from CAPPIMU Dataset

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import os

# Set up Paths for subjects 1-15
data_dir = Path('../data/raw/CAPPIMU/data')
subject_ids = range(1, 16) # subjects 1-16

for subject_id in subject_ids:
    subject_path = data_dir / f"S{subject_id}"
    print(f"Loading Subject {subject_id} from {subject_path}")
# Out:
# Loading Subject 1 from ..\data\raw\CAPPIMU\data\S1
# Loading Subject 2 from ..\data\raw\CAPPIMU\data\S2
# Loading Subject 3 from ..\data\raw\CAPPIMU\data\S3
# Loading Subject 4 from ..\data\raw\CAPPIMU\data\S4
# Loading Subject 5 from ..\data\raw\CAPPIMU\data\S5
# Loading Subject 6 from ..\data\raw\CAPPIMU\data\S6
# Loading Subject 7 from ..\data\raw\CAPPIMU\data\S7
# Loading Subject 8 from ..\data\raw\CAPPIMU\data\S8
# Loading Subject 9 from ..\data\raw\CAPPIMU\data\S9
# Loading Subject 10 from ..\data\raw\CAPPIMU\data\S10
# Loading Subject 11 from ..\data\raw\CAPPIMU\data\S11
# Loading Subject 12 from ..\data\raw\CAPPIMU\data\S12
# Loading Subject 13 from ..\data\raw\CAPPIMU\data\S13
# Loading Subject 14 from ..\data\raw\CAPPIMU\data\S14
# Loading Subject 15 from ..\data\raw\CAPPIMU\data\S15

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# Set up paths
data_dir = Path('../data/raw/CAPPIMU/data')

def read_subject_trial(subject_id, data_dir=data_dir):
    """
    Read all sensor data files for a given subject.
    """
    subject_path = data_dir / f'subject_{subject_id}'

    if not subject_path.exists():
        print(f"❌ Subject path not found: {subject_path.absolute()}")
        raise ValueError(f"Subject {subject_id} data not found")

    print(f"\n✓ Found subject directory: {subject_path}")

    sensor_files = [
        'chest', 'arm_l', 'arm_r', 'head', 'knee_l', 'knee_r',
        'pocket', 'wrist_l', 'wrist_r', 'insole'
    ]

    subject_data = {}

    for sensor in sensor_files:
        csv_path = subject_path / f'{sensor}.csv'
        if csv_path.exists():
            try:
                df = pd.read_csv(csv_path)
                subject_data[sensor] = df
                print(f"  ✓ Loaded {sensor}.csv ({df.shape})")
            except Exception as e:
                print(f"  ⚠️ Error reading {sensor}.csv: {e}")

    # Optional insole ankle
    insole_ankle_path = subject_path / 'insole_ankle.csv'
    if insole_ankle_path.exists():
        subject_data['insole_ankle'] = pd.read_csv(insole_ankle_path)

    # Joint data
    joint_dir = subject_path / 'joint'
    if joint_dir.exists():
        for joint_file in joint_dir.glob('*.csv'):
            subject_data[f'joint_{joint_file.stem}'] = pd.read_csv(joint_file)

    if not subject_data:
        print(f"⚠️ No sensor data found for subject {subject_id}")

    return subject_data

# %%
all_subjects_data = {}

for subject_id in range(1, 16):
    try:
        print(f"\n{'='*60}")
        print(f"Reading data for Subject {subject_id}")
        all_subjects_data[subject_id] = read_subject_trial(subject_id)
    except Exception as e:
        print(f"❌ Skipping Subject {subject_id}: {e}")
# Out:
# ============================================================
# Reading data for Subject 1
#
# ✓ Found subject directory: ..\data\raw\CAPPIMU\data\subject_1
#   ✓ Loaded chest.csv ((201852, 11))
#   ✓ Loaded arm_l.csv ((202738, 11))
#   ✓ Loaded arm_r.csv ((204889, 11))
#   ✓ Loaded head.csv ((205323, 11))
#   ✓ Loaded knee_l.csv ((203514, 11))
#   ✓ Loaded knee_r.csv ((200993, 11))
#   ✓ Loaded pocket.csv ((204265, 11))
#   ✓ Loaded wrist_l.csv ((201265, 11))
#   ✓ Loaded wrist_r.csv ((204611, 11))
#   ✓ Loaded insole.csv ((203655, 18))
#
# ============================================================
# Reading data for Subject 2
#
# ✓ Found subject directory: ..\data\raw\CAPPIMU\data\subject_2
#   ✓ Loaded chest.csv ((200039, 11))
#   ✓ Loaded arm_l.csv ((198656, 11))
#   ✓ Loaded arm_r.csv ((198763, 11))
#   ✓ Loaded head.csv ((201673, 11))
#   ✓ Loaded knee_l.csv ((200431, 11))
#   ✓ Loaded knee_r.csv ((200588, 11))
#   ✓ Loaded pocket.csv ((199962, 11))
#   ✓ Loaded wrist_l.csv ((198583, 11))
#   ✓ Loaded wrist_r.csv ((201425, 11))
#   ✓ Loaded insole.csv ((200906, 18))
# C:\Users\monya\AppData\Local\Temp\ipykernel_36140\10193304.py:40: DtypeWarning: Columns (13,23,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   subject_data['insole_ankle'] = pd.read_csv(insole_ankle_path)
# ============================================================
# Reading data for Subject 3
#
# ✓ Found subject directory: ..\data\raw\CAPPIMU\data\subject_3
#   ✓ Loaded chest.csv ((200720, 11))
#   ✓ Loaded arm_l.csv ((203359, 11))
#   ✓ Loaded arm_r.csv ((203254, 11))
#   ✓ Loaded head.csv ((203530, 11))
#   ✓ Loaded knee_l.csv ((201850, 11))
#   ✓ Loaded knee_r.csv ((199792, 11))
#   ✓ Loaded pocket.csv ((202676, 11))
#   ✓ Loaded wrist_l.csv ((202255, 11))
#   ✓ Loaded wrist_r.csv ((203292, 11))
#   ✓ Loaded insole.csv ((201042, 18))
# C:\Users\monya\AppData\Local\Temp\ipykernel_36140\10193304.py:40: DtypeWarning: Columns (12,13,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   subject_data['insole_ankle'] = pd.read_csv(insole_ankle_path)
# ============================================================
# Reading data for Subject 4
#
# ✓ Found subject directory: ..\data\raw\CAPPIMU\data\subject_4
#   ✓ Loaded chest.csv ((200967, 11))
#   ✓ Loaded arm_l.csv ((201134, 11))
#   ✓ Loaded arm_r.csv ((200800, 11))
#   ✓ Loaded head.csv ((201638, 11))
#   ✓ Loaded knee_l.csv ((197754, 11))
#   ✓ Loaded knee_r.csv ((190240, 11))
#   ✓ Loaded pocket.csv ((200562, 11))
#   ✓ Loaded wrist_l.csv ((200096, 11))
#   ✓ Loaded wrist_r.csv ((201229, 11))
#   ✓ Loaded insole.csv ((198803, 18))
# C:\Users\monya\AppData\Local\Temp\ipykernel_36140\10193304.py:40: DtypeWarning: Columns (9,11,12,26,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   subject_data['insole_ankle'] = pd.read_csv(insole_ankle_path)
# ============================================================
# Reading data for Subject 5
#
# ✓ Found subject directory: ..\data\raw\CAPPIMU\data\subject_5
#   ✓ Loaded chest.csv ((193442, 11))
#   ✓ Loaded arm_l.csv ((196483, 11))
#   ✓ Loaded arm_r.csv ((196383, 11))
#   ✓ Loaded head.csv ((196853, 11))
#   ✓ Loaded knee_l.csv ((193060, 11))
#   ✓ Loaded knee_r.csv ((195816, 11))
#   ✓ Loaded pocket.csv ((194837, 11))
#   ✓ Loaded wrist_l.csv ((192234, 11))
#   ✓ Loaded wrist_r.csv ((196632, 11))
#   ✓ Loaded insole.csv ((195687, 18))
# C:\Users\monya\AppData\Local\Temp\ipykernel_36140\10193304.py:40: DtypeWarning: Columns (9,11,12,25,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   subject_data['insole_ankle'] = pd.read_csv(insole_ankle_path)
# ============================================================
# Reading data for Subject 6
#
# ✓ Found subject directory: ..\data\raw\CAPPIMU\data\subject_6
#   ✓ Loaded chest.csv ((197668, 11))
#   ✓ Loaded arm_l.csv ((196415, 11))
#   ✓ Loaded arm_r.csv ((196121, 11))
#   ✓ Loaded head.csv ((199674, 11))
#   ✓ Loaded knee_l.csv ((198216, 11))
#   ✓ Loaded knee_r.csv ((195458, 11))
#   ✓ Loaded pocket.csv ((198827, 11))
#   ✓ Loaded wrist_l.csv ((196053, 11))
#   ✓ Loaded wrist_r.csv ((199000, 11))
#   ✓ Loaded insole.csv ((197861, 18))
#
# ============================================================
# Reading data for Subject 7
#
# ✓ Found subject directory: ..\data\raw\CAPPIMU\data\subject_7
#   ✓ Loaded chest.csv ((200096, 11))
#   ✓ Loaded arm_l.csv ((200408, 11))
#   ✓ Loaded arm_r.csv ((199855, 11))
#   ✓ Loaded head.csv ((200749, 11))
#   ✓ Loaded knee_l.csv ((197165, 11))
#   ✓ Loaded knee_r.csv ((188427, 11))
#   ✓ Loaded pocket.csv ((196168, 11))
#   ✓ Loaded wrist_l.csv ((199650, 11))
#   ✓ Loaded wrist_r.csv ((200564, 11))
#   ✓ Loaded insole.csv ((201171, 18))
#
# ============================================================
# Reading data for Subject 8
#
# ✓ Found subject directory: ..\data\raw\CAPPIMU\data\subject_8
#   ✓ Loaded chest.csv ((193130, 11))
#   ✓ Loaded arm_l.csv ((191503, 11))
#   ✓ Loaded arm_r.csv ((194274, 11))
#   ✓ Loaded head.csv ((194873, 11))
#   ✓ Loaded knee_l.csv ((193446, 11))
#   ✓ Loaded knee_r.csv ((193873, 11))
#   ✓ Loaded pocket.csv ((193857, 11))
#   ✓ Loaded wrist_l.csv ((187504, 11))
#   ✓ Loaded wrist_r.csv ((194316, 11))
#   ✓ Loaded insole.csv ((195633, 18))
#
# ============================================================
# Reading data for Subject 9
#
# ✓ Found subject directory: ..\data\raw\CAPPIMU\data\subject_9
#   ✓ Loaded chest.csv ((195142, 11))
#   ✓ Loaded arm_l.csv ((192345, 11))
#   ✓ Loaded arm_r.csv ((195336, 11))
#   ✓ Loaded head.csv ((195709, 11))
#   ✓ Loaded knee_l.csv ((194121, 11))
#   ✓ Loaded knee_r.csv ((191204, 11))
#   ✓ Loaded pocket.csv ((193484, 11))
#   ✓ Loaded wrist_l.csv ((193900, 11))
#   ✓ Loaded wrist_r.csv ((195339, 11))
#   ✓ Loaded insole.csv ((196885, 18))
#
# ============================================================
# Reading data for Subject 10
#
# ✓ Found subject directory: ..\data\raw\CAPPIMU\data\subject_10
#   ✓ Loaded chest.csv ((200238, 11))
#   ✓ Loaded arm_l.csv ((200416, 11))
#   ✓ Loaded arm_r.csv ((199241, 11))
#   ✓ Loaded head.csv ((200385, 11))
#   ✓ Loaded knee_l.csv ((197744, 11))
#   ✓ Loaded knee_r.csv ((191094, 11))
#   ✓ Loaded pocket.csv ((199508, 11))
#   ✓ Loaded wrist_l.csv ((199594, 11))
#   ✓ Loaded wrist_r.csv ((200214, 11))
#   ✓ Loaded insole.csv ((195930, 18))
# C:\Users\monya\AppData\Local\Temp\ipykernel_36140\10193304.py:40: DtypeWarning: Columns (12,13,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   subject_data['insole_ankle'] = pd.read_csv(insole_ankle_path)
# ============================================================
# Reading data for Subject 11
#
# ✓ Found subject directory: ..\data\raw\CAPPIMU\data\subject_11
#   ✓ Loaded chest.csv ((199696, 11))
#   ✓ Loaded arm_l.csv ((199947, 11))
#   ✓ Loaded arm_r.csv ((199250, 11))
#   ✓ Loaded head.csv ((199915, 11))
#   ✓ Loaded knee_l.csv ((198718, 11))
#   ✓ Loaded knee_r.csv ((198711, 11))
#   ✓ Loaded pocket.csv ((198956, 11))
#   ✓ Loaded wrist_l.csv ((198590, 11))
#   ✓ Loaded wrist_r.csv ((199716, 11))
#   ✓ Loaded insole.csv ((197692, 18))
# C:\Users\monya\AppData\Local\Temp\ipykernel_36140\10193304.py:40: DtypeWarning: Columns (11,13,14,25,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   subject_data['insole_ankle'] = pd.read_csv(insole_ankle_path)
# ============================================================
# Reading data for Subject 12
#
# ✓ Found subject directory: ..\data\raw\CAPPIMU\data\subject_12
#   ✓ Loaded chest.csv ((194984, 11))
#   ✓ Loaded arm_l.csv ((196744, 11))
#   ✓ Loaded arm_r.csv ((195762, 11))
#   ✓ Loaded head.csv ((196840, 11))
#   ✓ Loaded knee_l.csv ((194867, 11))
#   ✓ Loaded knee_r.csv ((192777, 11))
#   ✓ Loaded pocket.csv ((194179, 11))
#   ✓ Loaded wrist_l.csv ((196123, 11))
#   ✓ Loaded wrist_r.csv ((196527, 11))
#   ✓ Loaded insole.csv ((193795, 18))
#
# ============================================================
# Reading data for Subject 13
#
# ✓ Found subject directory: ..\data\raw\CAPPIMU\data\subject_13
#   ✓ Loaded chest.csv ((201070, 11))
#   ✓ Loaded arm_l.csv ((201207, 11))
#   ✓ Loaded arm_r.csv ((200994, 11))
#   ✓ Loaded head.csv ((201170, 11))
#   ✓ Loaded knee_l.csv ((199350, 11))
#   ✓ Loaded knee_r.csv ((199730, 11))
#   ✓ Loaded pocket.csv ((200439, 11))
#   ✓ Loaded wrist_l.csv ((200513, 11))
#   ✓ Loaded wrist_r.csv ((201006, 11))
#   ✓ Loaded insole.csv ((198478, 18))
# C:\Users\monya\AppData\Local\Temp\ipykernel_36140\10193304.py:40: DtypeWarning: Columns (9,23,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   subject_data['insole_ankle'] = pd.read_csv(insole_ankle_path)
# ============================================================
# Reading data for Subject 14
#
# ✓ Found subject directory: ..\data\raw\CAPPIMU\data\subject_14
#   ✓ Loaded chest.csv ((201056, 11))
#   ✓ Loaded arm_l.csv ((199547, 11))
#   ✓ Loaded arm_r.csv ((199677, 11))
#   ✓ Loaded head.csv ((201292, 11))
#   ✓ Loaded knee_l.csv ((198833, 11))
#   ✓ Loaded knee_r.csv ((191890, 11))
#   ✓ Loaded pocket.csv ((200634, 11))
#   ✓ Loaded wrist_l.csv ((199687, 11))
#   ✓ Loaded wrist_r.csv ((201136, 11))
#   ✓ Loaded insole.csv ((201053, 18))
# C:\Users\monya\AppData\Local\Temp\ipykernel_36140\10193304.py:40: DtypeWarning: Columns (10,11,14,23,26,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   subject_data['insole_ankle'] = pd.read_csv(insole_ankle_path)
# ============================================================
# Reading data for Subject 15
#
# ✓ Found subject directory: ..\data\raw\CAPPIMU\data\subject_15
#   ✓ Loaded chest.csv ((208367, 11))
#   ✓ Loaded arm_l.csv ((208018, 11))
#   ✓ Loaded arm_r.csv ((208511, 11))
#   ✓ Loaded head.csv ((208472, 11))
#   ✓ Loaded knee_l.csv ((207333, 11))
#   ✓ Loaded knee_r.csv ((208148, 11))
#   ✓ Loaded pocket.csv ((207796, 11))
#   ✓ Loaded wrist_l.csv ((205275, 11))
#   ✓ Loaded wrist_r.csv ((208330, 11))
#   ✓ Loaded insole.csv ((206388, 18))
# C:\Users\monya\AppData\Local\Temp\ipykernel_36140\10193304.py:40: DtypeWarning: Columns (9,10,11,12,26,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   subject_data['insole_ankle'] = pd.read_csv(insole_ankle_path)
